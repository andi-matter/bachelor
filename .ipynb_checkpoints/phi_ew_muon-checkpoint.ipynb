# %%
import numpy as np
import matplotlib.pyplot as plt


import math
import csv
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

import matplotlib as mpl
import seaborn as sns
 

#matplotlib.verbose.level = 'debug-annoying'
mpl.rcParams.update({'font.size': 16})
import sys
import os

sns.set_theme()
palette = sns.color_palette('colorblind')
sns.set_context("paper")
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set(font_scale=1.5, rc={'text.usetex' : True})

# %%
muon_angles_deg = np.asarray([0,
32.8877774405093,
89.9543738355392,
151.833815709668,
180,
208.166184290332,
270.045626164461,
327.112222559491,
])

muon_angles = np.asarray([0,
0.574,
1.57,
2.65,
3.14159265358979,
3.63318530717959,
4.71318530717959,
5.70918530717959
])

# %%
phi_ew_mean = np.asarray([-65.58,
-100.81,
-92.84,
-76.65,
-20.49,
-11.84,
-12.2,
-19.34,
])*2*np.pi/360

phi_ew_mean_deg_ref4 = np.asarray([158.44,
122.53,
130.24,
144.25,
-155.49,
-142.88,
-146.86,
-153.32
])

phi_ew_err_ref4_deg = np.asarray([2.37,
1.85,
0.74,
2.09,
1.45,
1.36,
0.54,
1.4])

phi_ew_mean_ref4 = np.asarray([158.44,
122.53,
130.24,
144.25,
-155.49,
-142.88,
-146.86,
-153.32
])*2*np.pi/360

phi_ew_ref4_err = np.asarray([2.37,
1.85,
0.74,
2.09,
1.45,
1.36,
0.54,
1.4])*2*np.pi/360


phi_ew_err = np.asarray([2.06,
1.55,
0.63,
1.73,
1.24,
2.46,
0.7,
2.18,
])*2*np.pi/360

phi_ew_mean_deg = np.asarray([-65.58,
-100.81,
-92.84,
-76.65,
-20.49,
-11.84,
-12.2,
-19.34,
])

phi_ew_err_deg = np.asarray([2.06,
1.55,
0.63,
1.73,
1.24,
2.46,
0.7,
2.18,
])

# %%
fig = plt.figure(figsize=(8,4))
plt.errorbar(muon_angles_deg, phi_ew_mean_deg_ref4, yerr=phi_ew_err_ref4_deg, linestyle='None', color="green")
plt.scatter(muon_angles_deg, phi_ew_mean_deg_ref4, marker=".", color="black")
plt.title(r"Phi_ew vs Phi_muon")
plt.xlabel(r"Phi_muon (deg.)")
plt.ylabel(r"Phi_ew_mean (deg.)")
# Out:
# Text(0, 0.5, 'Phi_ew_mean (deg.)')
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     276                                              cwd=self.texcache,
# --> 277                                              stderr=subprocess.STDOUT)
#     278         except FileNotFoundError as exc:
#
# ~\anaconda3\envs\test\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#
# ~\anaconda3\envs\test\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-interaction=nonstopmode', '--halt-on-error', 'C:\\Users\\uni\\.matplotlib\\tex.cache\\679f15c5e72f8d8ce347c7cf1c315652.tex']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2706                 artists.remove(spine)
#    2707
# -> 2708         self._update_title_position(renderer)
#    2709
#    2710         if not self.axison or inframe:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2642                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2643                         or ax.xaxis.get_label_position() == 'top'):
# -> 2644                     bb = ax.xaxis.get_tightbbox(renderer)
#    2645                 else:
#    2646                     bb = ax.get_window_extent(renderer)
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1127         # take care of label
#    1128         if self.label.get_visible():
# -> 1129             bb = self.label.get_window_extent(renderer)
#    1130             # for constrained/tight_layout, we want to ignore the label's
#    1131             # width/height because the adjustments they make can't be improved.
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     898
#     899         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 900             bbox, info, descent = self._get_layout(self._renderer)
#     901             x, y = self.get_unitless_position()
#     902             x, y = self.get_transform().transform((x, y))
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     292             if clean_line:
#     293                 w, h, d = renderer.get_text_width_height_descent(
# --> 294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#     296                 w = h = d = 0
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     226             fontsize = prop.get_size_in_points()
#     227             w, h, d = texmanager.get_text_width_height_descent(
# --> 228                 s, fontsize, renderer=self)
#     229             return w, h, d
#     230
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 311                      texfile], tex)
#     312             for fname in glob.glob(basefile + '*'):
#     313                 if not fname.endswith(('dvi', 'tex')):
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     288                     prog=command[0],
#     289                     tex=tex.encode('unicode_escape'),
# --> 290                     exc=exc.output.decode('utf-8'))) from exc
#     291         _log.debug(report)
#     292         return report
#
# RuntimeError: latex was not able to process the following string:
# b'Phi_muon (deg.)'
#
# Here is the full report generated by latex:
# This is pdfTeX, Version 3.141592653-2.6-1.40.24 (MiKTeX 22.1) (preloaded format=latex.fmt)
#  restricted \write18 enabled.
# entering extended mode
# (C:/Users/uni/.matplotlib/tex.cache/679f15c5e72f8d8ce347c7cf1c315652.tex
# LaTeX2e <2021-11-15> patch level 1
# L3 programming layer <2022-02-21>
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\article.cls
# Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\size10.clo))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/type1cm\type1cm.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/cm-super\type1ec.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\t1cmr.fd))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\inputenc.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/graphics\keyval.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/generic/iftex\ifvtex.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/generic/iftex\iftex.sty))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.cfg)
#
# Package geometry Warning: Over-specification in `h'-direction.
#     `width' (5058.9pt) is ignored.
#
#
# Package geometry Warning: Over-specification in `v'-direction.
#     `height' (5058.9pt) is ignored.
#
# ) (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\textcomp.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/l3backend\l3backend-dvips
# .def) (679f15c5e72f8d8ce347c7cf1c315652.aux)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.19 {\sffamily Phi_
#                     muon (deg.)}
# No pages of output.
# Transcript written on 679f15c5e72f8d8ce347c7cf1c315652.log.

# %%
# #ref channel 1
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='polar')
fig2 = plt.figure(figsize=(4,4))
ax2 = fig2.add_subplot(111)
ones = np.ones(len(muon_angles))
filled_markers = ('o', 'v', '^', '<', '>', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
positions = ["C2", "L2", "L0", "L1", "C1", "R1", "R0", "R2"]
x = [1, 1, 0, -1, -1, -1, 0, 1]
y = [0, 1, 1, 1, 0, -1, -1, -1]
ax.set_rorigin(-1)
ax.scatter(0, "", color="white")
for i in range(len(muon_angles)):
  ax.errorbar([ phi_ew_mean[i], muon_angles[i]], ["Phi_ew", "Phi_muon"], xerr=[phi_ew_err[i], 0], markersize=10, alpha=0.8, linestyle='None', color="black")
  ax.scatter([ phi_ew_mean[i], muon_angles[i]], ["Phi_ew", "Phi_muon"], label = positions[i], marker=filled_markers[i], s=100, alpha=0.8, linestyle='None')
  ax2.scatter(x[i], y[i],  marker=filled_markers[i], label = positions[i], s=100, alpha=0.8, linestyle='None')
ax.legend(loc="center right", bbox_to_anchor=(0.7, 0.2, 0.5, 0.5))
ax2.set_xlabel("Window")
ax2.set_title("Locations of measurements")
ax.set_title("Phi_muon with respective Phi_ew, phi_ew not in absolute position!")
ax2.legend(loc="center right", bbox_to_anchor=(0.8, 0.2, 0.5, 0.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     276                                              cwd=self.texcache,
# --> 277                                              stderr=subprocess.STDOUT)
#     278         except FileNotFoundError as exc:
#
# ~\anaconda3\envs\test\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#
# ~\anaconda3\envs\test\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-interaction=nonstopmode', '--halt-on-error', 'C:\\Users\\uni\\.matplotlib\\tex.cache\\89613651c8314f1ce8040ef00a94d5e1.tex']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\projections\polar.py in draw(self, renderer, *args, **kwargs)
#     993             self.yaxis.set_clip_path(self.patch)
#     994
# --> 995         Axes.draw(self, renderer, *args, **kwargs)
#     996
#     997     def _gen_axes_patch(self):
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2706                 artists.remove(spine)
#    2707
# -> 2708         self._update_title_position(renderer)
#    2709
#    2710         if not self.axison or inframe:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2647                 if bb is not None:
#    2648                     top = max(top, bb.ymax)
# -> 2649             if title.get_window_extent(renderer).ymin < top:
#    2650                 _, y = self.transAxes.inverted().transform((0, top))
#    2651                 title.set_position((x, y))
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     898
#     899         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 900             bbox, info, descent = self._get_layout(self._renderer)
#     901             x, y = self.get_unitless_position()
#     902             x, y = self.get_transform().transform((x, y))
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     292             if clean_line:
#     293                 w, h, d = renderer.get_text_width_height_descent(
# --> 294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#     296                 w = h = d = 0
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     226             fontsize = prop.get_size_in_points()
#     227             w, h, d = texmanager.get_text_width_height_descent(
# --> 228                 s, fontsize, renderer=self)
#     229             return w, h, d
#     230
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 311                      texfile], tex)
#     312             for fname in glob.glob(basefile + '*'):
#     313                 if not fname.endswith(('dvi', 'tex')):
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     288                     prog=command[0],
#     289                     tex=tex.encode('unicode_escape'),
# --> 290                     exc=exc.output.decode('utf-8'))) from exc
#     291         _log.debug(report)
#     292         return report
#
# RuntimeError: latex was not able to process the following string:
# b'Phi_muon with respective Phi_ew, phi_ew not in absolute position!'
#
# Here is the full report generated by latex:
# This is pdfTeX, Version 3.141592653-2.6-1.40.24 (MiKTeX 22.1) (preloaded format=latex.fmt)
#  restricted \write18 enabled.
# entering extended mode
# (C:/Users/uni/.matplotlib/tex.cache/89613651c8314f1ce8040ef00a94d5e1.tex
# LaTeX2e <2021-11-15> patch level 1
# L3 programming layer <2022-02-21>
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\article.cls
# Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\size10.clo))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/type1cm\type1cm.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/cm-super\type1ec.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\t1cmr.fd))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\inputenc.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/graphics\keyval.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/generic/iftex\ifvtex.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/generic/iftex\iftex.sty))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.cfg)
#
# Package geometry Warning: Over-specification in `h'-direction.
#     `width' (5058.9pt) is ignored.
#
#
# Package geometry Warning: Over-specification in `v'-direction.
#     `height' (5058.9pt) is ignored.
#
# ) (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\textcomp.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/l3backend\l3backend-dvips
# .def)
# No file 89613651c8314f1ce8040ef00a94d5e1.aux.
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.19 {\sffamily Phi_
#                     muon with respective Phi_ew, phi_ew not in absolute posi...
# No pages of output.
# Transcript written on 89613651c8314f1ce8040ef00a94d5e1.log.

# %%
#ref channel 4
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='polar')
fig2 = plt.figure(figsize=(4,4))
ax2 = fig2.add_subplot(111)
ones = np.ones(len(muon_angles))
filled_markers = ('o', 'v', '^', '<', '>', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
positions = ["C2", "L2", "L0", "L1", "C1", "R1", "R0", "R2"]
x = [1, 1, 0, -1, -1, -1, 0, 1]
y = [0, 1, 1, 1, 0, -1, -1, -1]
ax.set_rorigin(-1)
ax.scatter(0, "", color="white")
for i in range(len(muon_angles)):
  ax.errorbar([ phi_ew_mean_ref4[i], muon_angles[i]], ["Phi_ew", "Phi_muon"], xerr=[phi_ew_ref4_err[i], 0], markersize=10, alpha=0.8, linestyle='None', color="black")
  ax.scatter([ phi_ew_mean_ref4[i], muon_angles[i]], ["Phi_ew", "Phi_muon"], label = positions[i], marker=filled_markers[i], s=100, alpha=0.8, linestyle='None')
  ax2.scatter(x[i], y[i],  marker=filled_markers[i], label = positions[i], s=100, alpha=0.8, linestyle='None')
ax.legend(loc="center right", bbox_to_anchor=(0.7, 0.2, 0.5, 0.5))
ax2.set_xlabel("Window")
ax2.set_title("Locations of measurements")
ax.set_title("Phi_muon with respective Phi_ew, phi_ew not in absolute position!")
ax2.legend(loc="center right", bbox_to_anchor=(0.8, 0.2, 0.5, 0.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     276                                              cwd=self.texcache,
# --> 277                                              stderr=subprocess.STDOUT)
#     278         except FileNotFoundError as exc:
#
# ~\anaconda3\envs\test\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#
# ~\anaconda3\envs\test\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-interaction=nonstopmode', '--halt-on-error', 'C:\\Users\\uni\\.matplotlib\\tex.cache\\89613651c8314f1ce8040ef00a94d5e1.tex']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\projections\polar.py in draw(self, renderer, *args, **kwargs)
#     993             self.yaxis.set_clip_path(self.patch)
#     994
# --> 995         Axes.draw(self, renderer, *args, **kwargs)
#     996
#     997     def _gen_axes_patch(self):
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2706                 artists.remove(spine)
#    2707
# -> 2708         self._update_title_position(renderer)
#    2709
#    2710         if not self.axison or inframe:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2647                 if bb is not None:
#    2648                     top = max(top, bb.ymax)
# -> 2649             if title.get_window_extent(renderer).ymin < top:
#    2650                 _, y = self.transAxes.inverted().transform((0, top))
#    2651                 title.set_position((x, y))
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     898
#     899         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 900             bbox, info, descent = self._get_layout(self._renderer)
#     901             x, y = self.get_unitless_position()
#     902             x, y = self.get_transform().transform((x, y))
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     292             if clean_line:
#     293                 w, h, d = renderer.get_text_width_height_descent(
# --> 294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#     296                 w = h = d = 0
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     226             fontsize = prop.get_size_in_points()
#     227             w, h, d = texmanager.get_text_width_height_descent(
# --> 228                 s, fontsize, renderer=self)
#     229             return w, h, d
#     230
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 311                      texfile], tex)
#     312             for fname in glob.glob(basefile + '*'):
#     313                 if not fname.endswith(('dvi', 'tex')):
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     288                     prog=command[0],
#     289                     tex=tex.encode('unicode_escape'),
# --> 290                     exc=exc.output.decode('utf-8'))) from exc
#     291         _log.debug(report)
#     292         return report
#
# RuntimeError: latex was not able to process the following string:
# b'Phi_muon with respective Phi_ew, phi_ew not in absolute position!'
#
# Here is the full report generated by latex:
# This is pdfTeX, Version 3.141592653-2.6-1.40.24 (MiKTeX 22.1) (preloaded format=latex.fmt)
#  restricted \write18 enabled.
# entering extended mode
# (C:/Users/uni/.matplotlib/tex.cache/89613651c8314f1ce8040ef00a94d5e1.tex
# LaTeX2e <2021-11-15> patch level 1
# L3 programming layer <2022-02-21>
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\article.cls
# Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\size10.clo))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/type1cm\type1cm.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/cm-super\type1ec.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\t1cmr.fd))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\inputenc.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/graphics\keyval.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/generic/iftex\ifvtex.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/generic/iftex\iftex.sty))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.cfg)
#
# Package geometry Warning: Over-specification in `h'-direction.
#     `width' (5058.9pt) is ignored.
#
#
# Package geometry Warning: Over-specification in `v'-direction.
#     `height' (5058.9pt) is ignored.
#
# ) (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\textcomp.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/l3backend\l3backend-dvips
# .def) (89613651c8314f1ce8040ef00a94d5e1.aux)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.19 {\sffamily Phi_
#                     muon with respective Phi_ew, phi_ew not in absolute posi...
# No pages of output.
# Transcript written on 89613651c8314f1ce8040ef00a94d5e1.log.

# %%
phi_ew_ref0 = np.asarray([-21.07,
-57.15,
-49.37,
-35.89,
24.5,
37.03,
33.14,
26.52
])

phi_ew_err_ref0 = np.asarray([1.95,
1.76,
0.67,
1.85,
1.28,
1.22,
0.5,
1.26
])

# %%
#ref channel 0
fig = plt.figure(figsize=(8,4))
plt.errorbar(muon_angles_deg, phi_ew_ref0, yerr=phi_ew_err_ref0, linestyle='None', color="green")
plt.scatter(muon_angles_deg, phi_ew_ref0, marker=".", color="black")
plt.title("Phi_ew vs Phi_muon")
plt.xlabel("Phi_muon (deg.)")
plt.ylabel("Phi_ew_mean (deg.)")
# Out:
# Text(0, 0.5, 'Phi_ew_mean (deg.)')
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     276                                              cwd=self.texcache,
# --> 277                                              stderr=subprocess.STDOUT)
#     278         except FileNotFoundError as exc:
#
# ~\anaconda3\envs\test\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#
# ~\anaconda3\envs\test\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-interaction=nonstopmode', '--halt-on-error', 'C:\\Users\\uni\\.matplotlib\\tex.cache\\679f15c5e72f8d8ce347c7cf1c315652.tex']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2706                 artists.remove(spine)
#    2707
# -> 2708         self._update_title_position(renderer)
#    2709
#    2710         if not self.axison or inframe:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2642                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2643                         or ax.xaxis.get_label_position() == 'top'):
# -> 2644                     bb = ax.xaxis.get_tightbbox(renderer)
#    2645                 else:
#    2646                     bb = ax.get_window_extent(renderer)
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1127         # take care of label
#    1128         if self.label.get_visible():
# -> 1129             bb = self.label.get_window_extent(renderer)
#    1130             # for constrained/tight_layout, we want to ignore the label's
#    1131             # width/height because the adjustments they make can't be improved.
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     898
#     899         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 900             bbox, info, descent = self._get_layout(self._renderer)
#     901             x, y = self.get_unitless_position()
#     902             x, y = self.get_transform().transform((x, y))
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     292             if clean_line:
#     293                 w, h, d = renderer.get_text_width_height_descent(
# --> 294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#     296                 w = h = d = 0
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     226             fontsize = prop.get_size_in_points()
#     227             w, h, d = texmanager.get_text_width_height_descent(
# --> 228                 s, fontsize, renderer=self)
#     229             return w, h, d
#     230
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 311                      texfile], tex)
#     312             for fname in glob.glob(basefile + '*'):
#     313                 if not fname.endswith(('dvi', 'tex')):
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     288                     prog=command[0],
#     289                     tex=tex.encode('unicode_escape'),
# --> 290                     exc=exc.output.decode('utf-8'))) from exc
#     291         _log.debug(report)
#     292         return report
#
# RuntimeError: latex was not able to process the following string:
# b'Phi_muon (deg.)'
#
# Here is the full report generated by latex:
# This is pdfTeX, Version 3.141592653-2.6-1.40.24 (MiKTeX 22.1) (preloaded format=latex.fmt)
#  restricted \write18 enabled.
# entering extended mode
# (C:/Users/uni/.matplotlib/tex.cache/679f15c5e72f8d8ce347c7cf1c315652.tex
# LaTeX2e <2021-11-15> patch level 1
# L3 programming layer <2022-02-21>
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\article.cls
# Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\size10.clo))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/type1cm\type1cm.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/cm-super\type1ec.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\t1cmr.fd))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\inputenc.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/graphics\keyval.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/generic/iftex\ifvtex.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/generic/iftex\iftex.sty))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.cfg)
#
# Package geometry Warning: Over-specification in `h'-direction.
#     `width' (5058.9pt) is ignored.
#
#
# Package geometry Warning: Over-specification in `v'-direction.
#     `height' (5058.9pt) is ignored.
#
# ) (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\textcomp.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/l3backend\l3backend-dvips
# .def) (679f15c5e72f8d8ce347c7cf1c315652.aux)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.19 {\sffamily Phi_
#                     muon (deg.)}
# No pages of output.
# Transcript written on 679f15c5e72f8d8ce347c7cf1c315652.log.

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='polar')
fig2 = plt.figure(figsize=(4,4))
ax2 = fig2.add_subplot(111)
ones = np.ones(len(muon_angles))
filled_markers = ('o', 'v', '^', '<', '>', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
positions = ["C2", "L2", "L0", "L1", "C1", "R1", "R0", "R2"]
x = [1, 1, 0, -1, -1, -1, 0, 1]
y = [0, 1, 1, 1, 0, -1, -1, -1]
ax.set_rorigin(-1)
ax.scatter(0, "", marker='None', linestyle='None')
ax.scatter(0, 1.2, marker='None', linestyle='None')
for i in range(len(muon_angles)):
  ax.errorbar([ phi_ew_ref0[i]*2*np.pi/360], [1], xerr=[phi_ew_err_ref0[i]*2*np.pi/360], markersize=8, alpha=0.6, linestyle='None', color='black', marker='None')
  ax.scatter([ phi_ew_ref0[i]*2*np.pi/360], [1], label = positions[i], marker=filled_markers[i], s=100, alpha=1, linestyle='None', color=palette[i])
for i in range(len(muon_angles)): 
  ax2.scatter(x[i], y[i],  marker=filled_markers[i], label = positions[i], s=100, alpha=1, linestyle='None', color=palette[i])
ax.legend(loc="center right", bbox_to_anchor=(0.7, 0.2, 0.5, 0.5))
ax2.set_xlabel("Window")
ax2.set_title("Approximate locations of measurements on detector box (arbitrary units)")
ax.set_title("\Phi_{ew}")
ax2.legend(loc="center right", bbox_to_anchor=(0.9, 0.2, 0.5, 0.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     276                                              cwd=self.texcache,
# --> 277                                              stderr=subprocess.STDOUT)
#     278         except FileNotFoundError as exc:
#
# ~\anaconda3\envs\test\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#
# ~\anaconda3\envs\test\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-interaction=nonstopmode', '--halt-on-error', 'C:\\Users\\uni\\.matplotlib\\tex.cache\\4d2f97f82f53720598013536b745765f.tex']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\envs\test\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\projections\polar.py in draw(self, renderer, *args, **kwargs)
#     993             self.yaxis.set_clip_path(self.patch)
#     994
# --> 995         Axes.draw(self, renderer, *args, **kwargs)
#     996
#     997     def _gen_axes_patch(self):
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2706                 artists.remove(spine)
#    2707
# -> 2708         self._update_title_position(renderer)
#    2709
#    2710         if not self.axison or inframe:
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2647                 if bb is not None:
#    2648                     top = max(top, bb.ymax)
# -> 2649             if title.get_window_extent(renderer).ymin < top:
#    2650                 _, y = self.transAxes.inverted().transform((0, top))
#    2651                 title.set_position((x, y))
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     898
#     899         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 900             bbox, info, descent = self._get_layout(self._renderer)
#     901             x, y = self.get_unitless_position()
#     902             x, y = self.get_transform().transform((x, y))
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     292             if clean_line:
#     293                 w, h, d = renderer.get_text_width_height_descent(
# --> 294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#     296                 w = h = d = 0
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     226             fontsize = prop.get_size_in_points()
#     227             w, h, d = texmanager.get_text_width_height_descent(
# --> 228                 s, fontsize, renderer=self)
#     229             return w, h, d
#     230
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 311                      texfile], tex)
#     312             for fname in glob.glob(basefile + '*'):
#     313                 if not fname.endswith(('dvi', 'tex')):
#
# ~\anaconda3\envs\test\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     288                     prog=command[0],
#     289                     tex=tex.encode('unicode_escape'),
# --> 290                     exc=exc.output.decode('utf-8'))) from exc
#     291         _log.debug(report)
#     292         return report
#
# RuntimeError: latex was not able to process the following string:
# b'\\\\Phi_{ew}'
#
# Here is the full report generated by latex:
# This is pdfTeX, Version 3.141592653-2.6-1.40.24 (MiKTeX 22.1) (preloaded format=latex.fmt)
#  restricted \write18 enabled.
# entering extended mode
# (C:/Users/uni/.matplotlib/tex.cache/4d2f97f82f53720598013536b745765f.tex
# LaTeX2e <2021-11-15> patch level 1
# L3 programming layer <2022-02-21>
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\article.cls
# Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\size10.clo))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/type1cm\type1cm.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/cm-super\type1ec.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\t1cmr.fd))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\inputenc.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/graphics\keyval.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/generic/iftex\ifvtex.sty
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/generic/iftex\iftex.sty))
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.cfg)
#
# Package geometry Warning: Over-specification in `h'-direction.
#     `width' (5058.9pt) is ignored.
#
#
# Package geometry Warning: Over-specification in `v'-direction.
#     `height' (5058.9pt) is ignored.
#
# ) (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/base\textcomp.sty)
# (C:\Users\uni\AppData\Local\Programs\MiKTeX\tex/latex/l3backend\l3backend-dvips
# .def)
# No file 4d2f97f82f53720598013536b745765f.aux.
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.19 {\sffamily \Phi
#                     _{ew}}
# No pages of output.
# Transcript written on 4d2f97f82f53720598013536b745765f.log.
